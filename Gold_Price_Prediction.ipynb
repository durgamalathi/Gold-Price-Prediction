# %%
# !pip install yfinance -q

# %%
import yfinance as yf

gold = yf.download(
    "GC=F",
    start="2021-01-01",
    end="2026-08-29",
    auto_adjust=False
)

gold.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price         Adj Close        Close         High          Low         Open  \
# Ticker             GC=F         GC=F         GC=F         GC=F         GC=F
# Date
# 2021-01-04  1944.699951  1944.699951  1945.099976  1912.199951  1912.199951
# 2021-01-05  1952.699951  1952.699951  1952.699951  1941.300049  1941.699951
# 2021-01-06  1906.900024  1906.900024  1959.900024  1901.500000  1952.000000
# 2021-01-07  1912.300049  1912.300049  1926.699951  1912.000000  1922.599976
# 2021-01-08  1834.099976  1834.099976  1908.000000  1834.099976  1908.000000
#
# Price      Volume
# Ticker       GC=F
# Date
# 2021-01-04    154
# 2021-01-05    113
# 2021-01-06    331
# 2021-01-07    122
# 2021-01-08     60

# %%
gold.to_csv("/content/gold_price.csv")

print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
import pandas as pd

df = pd.read_csv("/content/gold_price.csv")

df.head()
# Out:
#         Price           Adj Close               Close                High  \
# 0      Ticker                GC=F                GC=F                GC=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-04   1944.699951171875   1944.699951171875  1945.0999755859375
# 3  2021-01-05   1952.699951171875   1952.699951171875   1952.699951171875
# 4  2021-01-06  1906.9000244140625  1906.9000244140625  1959.9000244140625
#
#                  Low               Open Volume
# 0               GC=F               GC=F   GC=F
# 1                NaN                NaN    NaN
# 2  1912.199951171875  1912.199951171875    154
# 3  1941.300048828125  1941.699951171875    113
# 4             1901.5             1952.0    331

# %%
import pandas as pd

df = pd.read_csv("/content/gold_price.csv")

df.head()
# Out:
#         Price           Adj Close               Close                High  \
# 0      Ticker                GC=F                GC=F                GC=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-04   1944.699951171875   1944.699951171875  1945.0999755859375
# 3  2021-01-05   1952.699951171875   1952.699951171875   1952.699951171875
# 4  2021-01-06  1906.9000244140625  1906.9000244140625  1959.9000244140625
#
#                  Low               Open Volume
# 0               GC=F               GC=F   GC=F
# 1                NaN                NaN    NaN
# 2  1912.199951171875  1912.199951171875    154
# 3  1941.300048828125  1941.699951171875    113
# 4             1901.5             1952.0    331

# %%
print("Dataset Shape:", df.shape)
print("\nColumns:")
print(df.columns)

print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Dataset Shape: (1424, 7)
#
# Columns:
# Index(['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')
#
# Missing Values:
# Price        0
# Adj Close    1
# Close        1
# High         1
# Low          1
# Open         1
# Volume       1
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
print(df.head())
# Out:
#         Price           Adj Close               Close                High  \
# 0      Ticker                GC=F                GC=F                GC=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-04   1944.699951171875   1944.699951171875  1945.0999755859375
# 3  2021-01-05   1952.699951171875   1952.699951171875   1952.699951171875
# 4  2021-01-06  1906.9000244140625  1906.9000244140625  1959.9000244140625
#
#                  Low               Open Volume
# 0               GC=F               GC=F   GC=F
# 1                NaN                NaN    NaN
# 2  1912.199951171875  1912.199951171875    154
# 3  1941.300048828125  1941.699951171875    113
# 4             1901.5             1952.0    331

# %%
print(df.columns.tolist())
# Out:
# ['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

# %%
print(df.head())
# Out:
#         Price           Adj Close               Close                High  \
# 0      Ticker                GC=F                GC=F                GC=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-04   1944.699951171875   1944.699951171875  1945.0999755859375
# 3  2021-01-05   1952.699951171875   1952.699951171875   1952.699951171875
# 4  2021-01-06  1906.9000244140625  1906.9000244140625  1959.9000244140625
#
#                  Low               Open Volume
# 0               GC=F               GC=F   GC=F
# 1                NaN                NaN    NaN
# 2  1912.199951171875  1912.199951171875    154
# 3  1941.300048828125  1941.699951171875    113
# 4             1901.5             1952.0    331

# %%
print(df.shape)
print(df.info())
# Out:
# (1424, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1424 entries, 0 to 1423
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1424 non-null   object
#  1   Adj Close  1423 non-null   object
#  2   Close      1423 non-null   object
#  3   High       1423 non-null   object
#  4   Low        1423 non-null   object
#  5   Open       1423 non-null   object
#  6   Volume     1423 non-null   object
# dtypes: object(7)
# memory usage: 78.0+ KB
# None

# %%
import pandas as pd

df = pd.read_csv("/content/gold_price.csv")

print("Columns:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())
# Out:
# Columns:
# ['Price', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
#
# First 5 rows:
#         Price           Adj Close               Close                High  \
# 0      Ticker                GC=F                GC=F                GC=F
# 1        Date                 NaN                 NaN                 NaN
# 2  2021-01-04   1944.699951171875   1944.699951171875  1945.0999755859375
# 3  2021-01-05   1952.699951171875   1952.699951171875   1952.699951171875
# 4  2021-01-06  1906.9000244140625  1906.9000244140625  1959.9000244140625
#
#                  Low               Open Volume
# 0               GC=F               GC=F   GC=F
# 1                NaN                NaN    NaN
# 2  1912.199951171875  1912.199951171875    154
# 3  1941.300048828125  1941.699951171875    113
# 4             1901.5             1952.0    331

# %%
import pandas as pd

# Dataset மீண்டும் load
df = pd.read_csv("/content/gold_price.csv", skiprows=2)

# Columns பெயர் சரி செய்தல்
df.columns = ['Date', 'Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']

# Date convert
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Date இல்லாத rows remove
df = df.dropna(subset=['Date'])

# Date order
df = df.sort_values('Date').reset_index(drop=True)

print(df.head())
print("\nShape:", df.shape)
# Out:
#         Date    Adj Close        Close         High          Low         Open  \
# 0 2021-01-04  1944.699951  1944.699951  1945.099976  1912.199951  1912.199951
# 1 2021-01-05  1952.699951  1952.699951  1952.699951  1941.300049  1941.699951
# 2 2021-01-06  1906.900024  1906.900024  1959.900024  1901.500000  1952.000000
# 3 2021-01-07  1912.300049  1912.300049  1926.699951  1912.000000  1922.599976
# 4 2021-01-08  1834.099976  1834.099976  1908.000000  1834.099976  1908.000000
#
#    Volume
# 0     154
# 1     113
# 2     331
# 3     122
# 4      60
#
# Shape: (1422, 7)

# %%
print(df.dtypes)
# Out:
# Date         datetime64[ns]
# Adj Close           float64
# Close               float64
# High                float64
# Low                 float64
# Open                float64
# Volume                int64
# dtype: object

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

plt.plot(df['Date'], df['Close'])

plt.title('Historical Gold Price')
plt.xlabel('Date')
plt.ylabel('Gold Price')

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
df['MA_7'] = df['Close'].rolling(window=7).mean()
df['MA_30'] = df['Close'].rolling(window=30).mean()

df = df.dropna()

df.head()
# Out:
#          Date    Adj Close        Close         High          Low  \
# 29 2021-02-16  1797.199951  1797.199951  1823.400024  1787.300049
# 30 2021-02-17  1771.099976  1771.099976  1789.699951  1768.800049
# 31 2021-02-18  1773.400024  1773.400024  1784.599976  1766.000000
# 32 2021-02-19  1775.800049  1775.800049  1787.599976  1764.300049
# 33 2021-02-22  1806.699951  1806.699951  1807.800049  1784.000000
#
#            Open  Volume         MA_7        MA_30
# 29  1820.900024    1141  1823.200003  1850.443339
# 30  1785.800049     614  1817.514282  1844.656673
# 31  1776.099976     587  1809.157139  1838.680009
# 32  1764.300049     118  1800.657139  1834.310010
# 33  1784.000000     165  1795.814279  1830.790007

# %%
X = df[['Open', 'High', 'Low', 'Volume', 'MA_7', 'MA_30']]
y = df['Close']

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())
# Out:
# Features:
#            Open         High          Low  Volume         MA_7        MA_30
# 29  1820.900024  1823.400024  1787.300049    1141  1823.200003  1850.443339
# 30  1785.800049  1789.699951  1768.800049     614  1817.514282  1844.656673
# 31  1776.099976  1784.599976  1766.000000     587  1809.157139  1838.680009
# 32  1764.300049  1787.599976  1764.300049     118  1800.657139  1834.310010
# 33  1784.000000  1807.800049  1784.000000     165  1795.814279  1830.790007
#
# Target:
# 29    1797.199951
# 30    1771.099976
# 31    1773.400024
# 32    1775.800049
# 33    1806.699951
# Name: Close, dtype: float64

# %%
split = int(len(df) * 0.8)

X_train = X.iloc[:split]
X_test = X.iloc[split:]

y_train = y.iloc[:split]
y_test = y.iloc[split:]

print("Training samples:", len(X_train))
print("Testing samples:", len(X_test))
# Out:
# Training samples: 1114
# Testing samples: 279

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(
    n_estimators=200,
    random_state=42
)

model.fit(X_train, y_train)

print("Model training completed!")
# Out:
# Model training completed!

# %%
y_pred = model.predict(X_test)

print("First 10 Predictions:")
print(y_pred[:10])
# Out:
# First 10 Predictions:
# [3403.81244385 3400.13794067 3370.22151855 3335.89401978 3325.24849609
#  3329.49151367 3303.71950317 3302.89648071 3314.40702026 3367.12097534]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

print("MAE :", mae)
print("RMSE:", rmse)
print("R² Score:", r2)
# Out:
# MAE : 874.7445832020749
# RMSE: 1000.7834063038686
# R² Score: -3.0368594899714134

# %%
plt.figure(figsize=(12, 6))

plt.plot(y_test.values, label='Actual')
plt.plot(y_pred, label='Predicted')

plt.title('Actual vs Predicted Gold Price')
plt.xlabel('Test Data')
plt.ylabel('Gold Price')
plt.legend()

plt.show()
